# %%
from numpy import mean
from numpy import std
from numpy.random import randn
from numpy.random import seed
from matplotlib import pyplot as plt

# %%
import pandas as pd

# %%
pkr_data = pd.read_csv("DHM, Pkr.csv")

# %%
pkr_data.describe()
# Out:
#             value  longitude      latitude    humidity    rainfall  \
# count  523.000000  523.00000  5.230000e+02  523.000000  523.000000
# mean    10.330593   83.97361  2.820582e+01   77.690249   17.179732
# std      4.545186    0.00000  7.112230e-15    4.590578   17.926473
# min      2.200000   83.97361  2.820582e+01   72.000000    2.000000
# 25%      6.800000   83.97361  2.820582e+01   72.500000    3.000000
# 50%     10.000000   83.97361  2.820582e+01   77.000000   13.000000
# 75%     12.800000   83.97361  2.820582e+01   81.500000   18.000000
# max     39.800000   83.97361  2.820582e+01   86.000000   60.000000
#
#        airTemperature
# count      523.000000
# mean        24.674952
# std          0.627227
# min         24.000000
# 25%         24.200000
# 50%         24.500000
# 75%         24.800000
# max         26.200000

# %%
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = pandas.read_csv(url, names=names)
correlations = data.corr()
# plot correlation matrix
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklab
