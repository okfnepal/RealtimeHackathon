# %%
from numpy import mean
from numpy import std
from numpy.random import randn
from numpy.random import seed
from matplotlib import pyplot as plt

# %%
import pandas as pd

# %%
pkr_data = pd.read_csv("DHM, Pkr.csv")

# %%
pkr_data.describe()
pkr_data.head()
# Out:
#   stationName parameters  value   localDateTime   unit  longitude   latitude  \
# 0    DHM, Pkr       pm25   12.9  7/19/2019 0:18  µg/m3   83.97361  28.205817
# 1    DHM, Pkr       pm25   11.6  7/19/2019 0:38  µg/m3   83.97361  28.205817
# 2    DHM, Pkr       pm25   10.3  7/19/2019 0:58  µg/m3   83.97361  28.205817
# 3    DHM, Pkr       pm25    9.9  7/19/2019 1:18  µg/m3   83.97361  28.205817
# 4    DHM, Pkr       pm25   11.6  7/19/2019 1:38  µg/m3   83.97361  28.205817
#
#    humidity  rainfall  airTemperature
# 0      77.0        60            24.2
# 1      77.0        60            24.2
# 2      77.0        60            24.2
# 3      77.0        60            24.2
# 4      77.0        60            24.2

# %%
import numpy as np
names = ['value', 'humidity', 'rainfall', 'airTemperature']
data = pkr_data.drop(['latitude', 'longitude'], axis=1)
correlations = data.corr()
# plot correlation matrix
fig = plt.figure(figsize=(20, 20))
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
print(correlations)
fig.colorbar(cax)
ticks = np.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
# Out:
#                    value  humidity  rainfall  airTemperature
# value           1.000000 -0.159889  0.073550       -0.071141
# humidity       -0.159889  1.000000  0.076905       -0.373023
# rainfall        0.073550  0.076905  1.000000       -0.355022
# airTemperature -0.071141 -0.373023 -0.355022        1.000000
# [Text(0, 0, 'value'),
#  Text(0, 0, 'humidity'),
#  Text(0, 0, 'rainfall'),
#  Text(0, 0, 'airTemperature')]
